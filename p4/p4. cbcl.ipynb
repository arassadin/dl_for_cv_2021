# %% [markdown]
# # Common

# %%
import os
import numpy as np
from sklearn import neighbors as knn
from glob import glob
from tqdm.notebook import tqdm
import cv2
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
from sklearn.metrics import balanced_accuracy_score, confusion_matrix
import itertools
import dlib
from natsort import natsorted

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = '/content/drive/MyDrive/dl_for_cv/data/cbcl/'

# %% [markdown]
# # MIT-CBCL

# %% [markdown]
# Download the dataset from [here](http://cbcl.mit.edu/software-datasets/heisele/facerecognition-database.html) and place it on your Google Drive in the folder set above.

# %% [markdown]
# # Dataset preparation

# %% [markdown]
# First of all, extract all the data:

# %%
# %cd $DATA_DIR
# !unzip -o MIT-CBCL-facerec-database.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: test/0001_00737.pgm
#   inflating: test/0001_00738.pgm
#   inflating: test/0001_00739.pgm
#   inflating: test/0001_00740.pgm
#   inflating: test/0001_00741.pgm
#   inflating: test/0001_00742.pgm
#   inflating: test/0001_00743.pgm
#   inflating: test/0001_00745.pgm
#   inflating: test/0001_00794.pgm
#   inflating: test/0001_00795.pgm
#   inflating: test/0001_00798.pgm
#   inflating: test/0001_00802.pgm
#   inflating: test/0001_00803.pgm
#   inflating: test/0001_00804.pgm
#   inflating: test/0001_00865.pgm
#   inflating: test/0001_00866.pgm
#   inflating: test/0001_00868.pgm
#   inflating: test/0001_00870.pgm
#   inflating: test/0001_00923.pgm
#   inflating: test/0001_00926.pgm
#   inflating: test/0001_01255.pgm
#   inflating: test/0001_01263.pgm
#   inflating: test/0001_01265.pgm
#   inflating: test/0001_01268.pgm
#   inflating: test/0001_01269.pgm
#   inflating: test/0001_01270.pgm
#   inflating: test/0001_01271.pgm
#   inflating: test/0001_01272.pgm
#   inflating: test/0001_01273.pgm
#   inflating: test/0001_01274.pgm
#   inflating: test/0001_01277.pgm
#   inflating: test/0001_01280.pgm
#   inflating: test/0001_01282.pgm
#   inflating: test/0001_01284.pgm
#   inflating: test/0001_01289.pgm
#   inflating: test/0001_01296.pgm
#   inflating: test/0001_01297.pgm
#   inflating: test/0001_01298.pgm
#   inflating: test/0001_01300.pgm
#   inflating: test/0001_01301.pgm
#   inflating: test/0001_01302.pgm
#   inflating: test/0001_01307.pgm
#   inflating: test/0001_01356.pgm
#   inflating: test/0001_01362.pgm
#   inflating: test/0001_01369.pgm
#   inflating: test/0001_01415.pgm
#   inflating: test/0001_01417.pgm
#   inflating: test/0001_01419.pgm
#   inflating: test/0001_01422.pgm
#   inflating: test/0001_01424.pgm
#   inflating: test/0001_01425.pgm
#   inflating: test/0001_01427.pgm
#   inflating: test/0001_01429.pgm
#   inflating: test/0001_01430.pgm
#   inflating: test/0001_01433.pgm
#   inflating: test/0001_01440.pgm
#   inflating: test/0001_01479.pgm
#   inflating: test/0001_01481.pgm
#   inflating: test/0001_01486.pgm
#   inflating: test/0001_01488.pgm
#   inflating: test/0001_01489.pgm
#   inflating: test/0001_01490.pgm
#   inflating: test/0001_01558.pgm
#   inflating: test/0001_01566.pgm
#   inflating: test/0001_01569.pgm
#   inflating: test/0001_01596.pgm
#   inflating: test/0002_j_00793.pgm
#   inflating: test/0002_j_00986.pgm
#   inflating: test/0002_j_00992.pgm
#   inflating: test/0002_j_01006.pgm
#   inflating: test/0002_j_01008.pgm
#   inflating: test/0002_j_01010.pgm
#   inflating: test/0002_j_01015.pgm
#   inflating: test/0002_j_01017.pgm
#   inflating: test/0002_j_01018.pgm
#   inflating: test/0002_j_01020.pgm
#   inflating: test/0002_j_01021.pgm
#   inflating: test/0002_j_01023.pgm
#   inflating: test/0002_j_01024.pgm
#   inflating: test/0002_j_01026.pgm
#   inflating: test/0002_j_01027.pgm
#   inflating: test/0002_j_01028.pgm
#   inflating: test/0002_j_01029.pgm
#   inflating: test/0002_j_01031.pgm
#   inflating: test/0002_j_01032.pgm
#   inflating: test/0002_j_01033.pgm
#   inflating: test/0002_j_01036.pgm
#   inflating: test/0002_j_01041.pgm
#   inflating: test/0002_j_01044.pgm
#   inflating: test/0002_j_01046.pgm
#   inflating: test/0002_j_01051.pgm
#   inflating: test/0002_j_01052.pgm
#   inflating: test/0002_j_01055.pgm
#   inflating: test/0002_j_01057.pgm
#   inflating: test/0002_j_01059.pgm
#   inflating: test/0002_j_01060.pgm
#   inflating: test/0002_j_01061.pgm
#   inflating: test/0002_j_01062.pgm
#   inflating: test/0002_j_01063.pgm
#   inflating: test/0002_j_01064.pgm
#   inflating: test/0002_j_01065.pgm
#   inflating: test/0002_j_01066.pgm
#   inflating: test/0002_j_01067.pgm
#   inflating: test/0002_j_01068.pgm
#   inflating: test/0002_j_01072.pgm
#   inflating: test/0002_j_01074.pgm
#   inflating: test/0002_j_01076.pgm
#   inflating: test/0002_j_01078.pgm
#   inflating: test/0002_j_01079.pgm
#   inflating: test/0002_j_01080.pgm
#   inflating: test/0002_j_01091.pgm
#   inflating: test/0002_j_01092.pgm
#   inflating: test/0002_j_01094.pgm
#   inflating: test/0002_j_01095.pgm
#   inflating: test/0002_j_01096.pgm
#   inflating: test/0002_j_01098.pgm
#   inflating: test/0002_j_01100.pgm
#   inflating: test/0002_j_01103.pgm
#   inflating: test/0002_j_01104.pgm
#   inflating: test/0002_j_01105.pgm
#   inflating: test/0002_j_01115.pgm
#   inflating: test/0002_j_01118.pgm
#   inflating: test/0002_j_01120.pgm
#   inflating: test/0002_j_01123.pgm
#   inflating: test/0002_j_01125.pgm
#   inflating: test/0002_j_01129.pgm
#   inflating: test/0002_j_01131.pgm
#   inflating: test/0002_j_01132.pgm
#   inflating: test/0002_j_01133.pgm
#   inflating: test/0002_j_01141.pgm
#   inflating: test/0002_j_01142.pgm
#   inflating: test/0002_j_01143.pgm
#   inflating: test/0002_j_01144.pgm
#   inflating: test/0002_j_01145.pgm
#   inflating: test/0002_j_01194.pgm
#   inflating: test/0002_j_01195.pgm
#   inflating: test/0002_j_01198.pgm
#   inflating: test/0002_j_01200.pgm
#   inflating: test/0002_j_01201.pgm
#   inflating: test/0002_j_01202.pgm
#   inflating: test/0002_j_01203.pgm
#   inflating: test/0002_j_01204.pgm
#   inflating: test/0002_j_01207.pgm
#   inflating: test/0004_06841.pgm
#   inflating: test/0004_06842.pgm
#   inflating: test/0004_06843.pgm
#   inflating: test/0004_06844.pgm
#   inflating: test/0004_06845.pgm
#   inflating: test/0004_06846.pgm
#   inflating: test/0004_06851.pgm
#   inflating: test/0004_06853.pgm
#   inflating: test/0004_06854.pgm
#   inflating: test/0004_06855.pgm
#   inflating: test/0004_06856.pgm
#   inflating: test/0004_06857.pgm
#   inflating: test/0004_06859.pgm
#   inflating: test/0004_06872.pgm
#   inflating: test/0004_06885.pgm
#   inflating: test/0004_06886.pgm
#   inflating: test/0004_06887.pgm
#   inflating: test/0004_06888.pgm
#   inflating: test/0004_06892.pgm
#   inflating: test/0004_06893.pgm
#   inflating: test/0004_06894.pgm
#   inflating: test/0004_06895.pgm
#   inflating: test/0004_06896.pgm
#   inflating: test/0004_06897.pgm
#   inflating: test/0004_06898.pgm
#   inflating: test/0004_06899.pgm
#   inflating: test/0004_06900.pgm
#   inflating: test/0004_06902.pgm
#   inflating: test/0004_06903.pgm
#   inflating: test/0004_06904.pgm
#   inflating: test/0004_06905.pgm
#   inflating: test/0004_06906.pgm
#   inflating: test/0004_06933.pgm
#   inflating: test/0004_06935.pgm
#   inflating: test/0004_06963.pgm
#   inflating: test/0004_06970.pgm
#   inflating: test/0004_06973.pgm
#   inflating: test/0004_06998.pgm
#   inflating: test/0004_07000.pgm
#   inflating: test/0004_07012.pgm
#   inflating: test/0004_07034.pgm
#   inflating: test/0004_07037.pgm
#   inflating: test/0004_07042.pgm
#   inflating: test/0004_07058.pgm
#   inflating: test/0004_07059.pgm
#   inflating: test/0004_07060.pgm
#   inflating: test/0004_07061.pgm
#   inflating: test/0004_07062.pgm
#   inflating: test/0004_07065.pgm
#   inflating: test/0004_07066.pgm
#   inflating: test/0004_07067.pgm
#   inflating: test/0004_07068.pgm
#   inflating: test/0004_07069.pgm
#   inflating: test/0004_07072.pgm
#   inflating: test/0004_07108.pgm
#   inflating: test/0004_07110.pgm
#   inflating: test/0004_07117.pgm
#   inflating: test/0004_07142.pgm
#   inflating: test/0004_07145.pgm
#   inflating: test/0004_07212.pgm
#   inflating: test/0004_07215.pgm
#   inflating: test/0004_ct_00000.pgm
#   inflating: test/0004_ct_00001.pgm
#   inflating: test/0004_ct_00002.pgm
#   inflating: test/0004_ct_00003.pgm
#   inflating: test/0004_ct_00004.pgm
#   inflating: test/0004_ct_00005.pgm
#   inflating: test/0004_ct_00006.pgm
#   inflating: test/0004_ct_00007.pgm
#   inflating: test/0004_ct_00008.pgm
#   inflating: test/0004_ct_00009.pgm
#   inflating: test/0004_ct_00011.pgm
#   inflating: test/0004_ct_00012.pgm
#   inflating: test/0004_ct_00013.pgm
#   inflating: test/0004_ct_00014.pgm
#   inflating: test/0004_ct_00015.pgm
#   inflating: test/0004_ct_00016.pgm
#   inflating: test/0004_ct_00017.pgm
#   inflating: test/0004_ct_00018.pgm
#   inflating: test/0004_ct_00019.pgm
#   inflating: test/0004_ct_00020.pgm
#   inflating: test/0004_ct_00021.pgm
#   inflating: test/0005_mt_00419.pgm
#   inflating: test/0005_mt_00420.pgm
#   inflating: test/0005_mt_00421.pgm
#   inflating: test/0005_mt_00422.pgm
#   inflating: test/0005_mt_00423.pgm
#   inflating: test/0005_mt_00425.pgm
#   inflating: test/0005_mt_00426.pgm
#   inflating: test/0005_mt_00427.pgm
#   inflating: test/0005_mt_00428.pgm
#   inflating: test/0005_mt_00429.pgm
#   inflating: test/0005_mt_00430.pgm
#   inflating: test/0005_mt_00431.pgm
#   inflating: test/0005_mt_00432.pgm
#   inflating: test/0005_mt_00435.pgm
#   inflating: test/0005_mt_00456.pgm
#   inflating: test/0005_mt_00458.pgm
#   inflating: test/0005_mt_00470.pgm
#   inflating: test/0005_mt_00471.pgm
#   inflating: test/0005_mt_00472.pgm
#   inflating: test/0005_mt_00473.pgm
#   inflating: test/0005_mt_00477.pgm
#   inflating: test/0005_mt_00492.pgm
#   inflating: test/0005_mt_00499.pgm
#   inflating: test/0005_mt_00501.pgm
#   inflating: test/0005_mt_00521.pgm
#   inflating: test/0005_mt_00528.pgm
#   inflating: test/0005_mt_00546.pgm
#   inflating: test/0005_mt_00547.pgm
#   inflating: test/0005_mt_00560.pgm
#   inflating: test/0005_mt_00596.pgm
#   inflating: test/0005_mt_00598.pgm
#   inflating: test/0005_mt_00622.pgm
#   inflating: test/0005_mt_00623.pgm
#   inflating: test/0005_mt_00625.pgm
#   inflating: test/0005_mt_00626.pgm
#   inflating: test/0005_mt_00636.pgm
#   inflating: test/0005_mt_00640.pgm
#   inflating: test/0005_mt_00698.pgm
#   inflating: test/0005_mt_00700.pgm
#   inflating: test/0005_mt_00701.pgm
#   inflating: test/0005_mt_00702.pgm
#   inflating: test/0005_mt_00703.pgm
#   inflating: test/0005_mt_00756.pgm
#   inflating: test/0005_mt_00760.pgm
#   inflating: test/0005_mt_00761.pgm
#   inflating: test/0005_mt_00762.pgm
#   inflating: test/0005_mt_00766.pgm
#   inflating: test/0005_mt_00767.pgm
#   inflating: test/0005_mt_00768.pgm
#   inflating: test/0005_mt_00769.pgm
#   inflating: test/0005_mt_00770.pgm
#   inflating: test/0005_mt_00773.pgm
#   inflating: test/0005_mt_00776.pgm
#   inflating: test/0005_mt_00790.pgm
#   inflating: test/0005_mt_00791.pgm
#   inflating: test/0005_mt_00793.pgm
#   inflating: test/0005_mt_00794.pgm
#   inflating: test/0005_mt_00795.pgm
#   inflating: test/0005_mt_00806.pgm
#   inflating: test/0005_mt_00808.pgm
#   inflating: test/0005_mt_00811.pgm
#   inflating: test/0005_mt_00871.pgm
#   inflating: test/0005_mt_00878.pgm
#   inflating: test/0005_mt_01803.pgm
#   inflating: test/0005_mt_01866.pgm
#   inflating: test/0005_mt_02141.pgm
#   inflating: test/0005_mt_02142.pgm
#   inflating: test/0005_mt_02143.pgm
#   inflating: test/0005_mt_02144.pgm
#   inflating: test/0005_mt_02145.pgm
#   inflating: test/0005_mt_02147.pgm
#   inflating: test/0005_mt_02149.pgm
#   inflating: test/0005_mt_02150.pgm
0_1.pgm
#   inflating: training-synthetic/0009_-8_0_0_0_90_15_1.pgm
#   inflating: training-synthetic/0009_-8_0_0_0_90_30_1.pgm
#   inflating: training-synthetic/0009_-8_0_0_0_90_45_1.pgm
#   inflating: training-synthetic/0009_-8_0_0_0_90_60_1.pgm
#   inflating: training-synthetic/0009_-8_0_0_0_90_75_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_15_0_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_15_15_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_15_30_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_15_45_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_15_60_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_15_75_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_30_0_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_30_15_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_30_30_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_30_45_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_30_60_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_30_75_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_45_0_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_45_15_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_45_30_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_45_45_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_45_60_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_45_75_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_60_0_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_60_15_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_60_30_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_60_45_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_60_60_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_60_75_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_75_0_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_75_15_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_75_30_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_75_45_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_75_60_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_75_75_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_90_0_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_90_15_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_90_30_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_90_45_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_90_60_1.pgm
#   inflating: training-synthetic/0009_0_0_0_0_90_75_1.pgm
#   inflating: readme.txt

# %% [markdown]
# Here we go..

# %%
files_db = [
    '0000_00000001.jpg', '0001_00000001.jpg', '0002_1.jpg', 
    '0003_00000001.jpg', '0004_1.jpg', '0005_16.jpg', '0006_001.jpg'
]

print(len(files_db))
# Out:
# 7

# %%
files_query = [
               os.path.basename(f) for f in glob(os.path.join(
                   DATA_DIR, 
                   'training-originals', 
                   '*.jpg'
                   ))
               ]
files_query = np.asarray(natsorted([f for f in files_query if f not in files_db]))

print(files_query.shape)
# Out:
# (52,)

# %%
files_query
# Out:
# array(['0000_00000002.jpg', '0000_00000003.jpg', '0000_00000004.jpg',
#        '0000_00000005.jpg', '0001_00000002.jpg', '0001_00000003.jpg',
#        '0001_00000004.jpg', '0001_00000005.jpg', '0002_2.jpg',
#        '0002_3.jpg', '0002_4.jpg', '0002_5.jpg', '0002_7.jpg',
#        '0003_00000002.jpg', '0003_00000003.jpg', '0003_00000004.jpg',
#        '0003_00000005.jpg', '0004_2.jpg', '0004_3.jpg', '0004_4.jpg',
#        '0004_5.jpg', '0004_6.jpg', '0005_17.jpg', '0005_18.jpg',
#        '0005_19.jpg', '0005_20.jpg', '0005_21.jpg', '0005_22.jpg',
#        '0005_23.jpg', '0006_002.jpg', '0006_003.jpg', '0006_004.jpg',
#        '0006_005.jpg', '0006_006.jpg', '0007_002.jpg', '0007_003.jpg',
#        '0007_004.jpg', '0007_005.jpg', '0007_006.jpg', '0008_001.jpg',
#        '0008_002.jpg', '0008_003.jpg', '0008_004.jpg', '0008_005.jpg',
#        '0008_006.jpg', '0008_007.jpg', '0009_002.jpg', '0009_003.jpg',
#        '0009_004.jpg', '0009_005.jpg', '0009_006.jpg', '0009_007.jpg'],
#       dtype='<U17')

# %% [markdown]
# # 1st-level predictor

# %%
# %cd /content/drive/MyDrive/dl_for_cv/
# Out:
# /content/drive/MyDrive/dl_for_cv

# %% [markdown]
# Our 1st-level predictor (aka embedding generator). Essentially this is ResNet-50 slighlty modified for REID heads. See [origin](https://github.com/TreB1eN/InsightFace_Pytorch) and big thanks authors for their work!

# %%
FACE_SIZE = 112

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# %% [markdown]
# *Model definition from [this file](https://github.com/TreB1eN/InsightFace_Pytorch/blob/master/model.py).*

# %%
from torch.nn import Linear, Conv2d, BatchNorm1d, BatchNorm2d, PReLU, ReLU, Sigmoid, Dropout, MaxPool2d, AdaptiveAvgPool2d, Sequential, Module
from collections import namedtuple

class Flatten(Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

def l2_norm(input,axis=1):
    norm = torch.norm(input,2,axis,True)
    output = torch.div(input, norm)
    return output

class SEModule(Module):
    def __init__(self, channels, reduction):
        super(SEModule, self).__init__()
        self.avg_pool = AdaptiveAvgPool2d(1)
        self.fc1 = Conv2d(
            channels, channels // reduction, kernel_size=1, padding=0 ,bias=False)
        self.relu = ReLU(inplace=True)
        self.fc2 = Conv2d(
            channels // reduction, channels, kernel_size=1, padding=0 ,bias=False)
        self.sigmoid = Sigmoid()

    def forward(self, x):
        module_input = x
        x = self.avg_pool(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return module_input * x

class bottleneck_IR(Module):
    def __init__(self, in_channel, depth, stride):
        super(bottleneck_IR, self).__init__()
        if in_channel == depth:
            self.shortcut_layer = MaxPool2d(1, stride)
        else:
            self.shortcut_layer = Sequential(
                Conv2d(in_channel, depth, (1, 1), stride ,bias=False), BatchNorm2d(depth))
        self.res_layer = Sequential(
            BatchNorm2d(in_channel),
            Conv2d(in_channel, depth, (3, 3), (1, 1), 1 ,bias=False), PReLU(depth),
            Conv2d(depth, depth, (3, 3), stride, 1 ,bias=False), BatchNorm2d(depth))

    def forward(self, x):
        shortcut = self.shortcut_layer(x)
        res = self.res_layer(x)
        return res + shortcut

class bottleneck_IR_SE(Module):
    def __init__(self, in_channel, depth, stride):
        super(bottleneck_IR_SE, self).__init__()
        if in_channel == depth:
            self.shortcut_layer = MaxPool2d(1, stride)
        else:
            self.shortcut_layer = Sequential(
                Conv2d(in_channel, depth, (1, 1), stride ,bias=False), 
                BatchNorm2d(depth))
        self.res_layer = Sequential(
            BatchNorm2d(in_channel),
            Conv2d(in_channel, depth, (3,3), (1,1),1 ,bias=False),
            PReLU(depth),
            Conv2d(depth, depth, (3,3), stride, 1 ,bias=False),
            BatchNorm2d(depth),
            SEModule(depth,16)
            )
    def forward(self,x):
        shortcut = self.shortcut_layer(x)
        res = self.res_layer(x)
        return res + shortcut

class Bottleneck(namedtuple('Block', ['in_channel', 'depth', 'stride'])):
    '''A named tuple describing a ResNet block.'''
    
def get_block(in_channel, depth, num_units, stride = 2):
  return [Bottleneck(in_channel, depth, stride)] + [Bottleneck(depth, depth, 1) for i in range(num_units-1)]

def get_blocks(num_layers):
    if num_layers == 50:
        blocks = [
            get_block(in_channel=64, depth=64, num_units = 3),
            get_block(in_channel=64, depth=128, num_units=4),
            get_block(in_channel=128, depth=256, num_units=14),
            get_block(in_channel=256, depth=512, num_units=3)
        ]
    elif num_layers == 100:
        blocks = [
            get_block(in_channel=64, depth=64, num_units=3),
            get_block(in_channel=64, depth=128, num_units=13),
            get_block(in_channel=128, depth=256, num_units=30),
            get_block(in_channel=256, depth=512, num_units=3)
        ]
    elif num_layers == 152:
        blocks = [
            get_block(in_channel=64, depth=64, num_units=3),
            get_block(in_channel=64, depth=128, num_units=8),
            get_block(in_channel=128, depth=256, num_units=36),
            get_block(in_channel=256, depth=512, num_units=3)
        ]
    return blocks

class Backbone(Module):
    def __init__(self, num_layers, drop_ratio, mode='ir'):
        super(Backbone, self).__init__()
        assert num_layers in [50, 100, 152], 'num_layers should be 50,100, or 152'
        assert mode in ['ir', 'ir_se'], 'mode should be ir or ir_se'
        blocks = get_blocks(num_layers)
        if mode == 'ir':
            unit_module = bottleneck_IR
        elif mode == 'ir_se':
            unit_module = bottleneck_IR_SE
        self.input_layer = Sequential(Conv2d(3, 64, (3, 3), 1, 1 ,bias=False), 
                                      BatchNorm2d(64), 
                                      PReLU(64))
        self.output_layer = Sequential(BatchNorm2d(512), 
                                       Dropout(drop_ratio),
                                       Flatten(),
                                       Linear(512 * 7 * 7, 512),
                                       BatchNorm1d(512))
        modules = []
        for block in blocks:
            for bottleneck in block:
                modules.append(
                    unit_module(bottleneck.in_channel,
                                bottleneck.depth,
                                bottleneck.stride))
        self.body = Sequential(*modules)
    
    def forward(self,x):
        x = self.input_layer(x)
        x = self.body(x)
        x = self.output_layer(x)
        return l2_norm(x)

# %% [markdown]
# Model weights are from [here](https://github.com/TreB1eN/InsightFace_Pytorch#32-detect-over-camera). **Please download it manually**.

# %%
model = Backbone(50, 0.0, mode='ir_se').eval()
model.load_state_dict(torch.load('model_ir_se50.pth'))
model.cuda()
# Out:
# Backbone(
#   (input_layer): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): PReLU(num_parameters=64)
#   )
#   (output_layer): Sequential(
#     (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Dropout(p=0.0, inplace=False)
#     (2): Flatten()
#     (3): Linear(in_features=25088, out_features=512, bias=True)
#     (4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (body): Sequential(
#     (0): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=64)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=64)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (2): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=64)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (3): bottleneck_IR_SE(
#       (shortcut_layer): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (res_layer): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=128)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (4): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=128)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (5): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=128)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (6): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=128)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (7): bottleneck_IR_SE(
#       (shortcut_layer): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (res_layer): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (8): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (9): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (10): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (11): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (12): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (13): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (14): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (15): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (16): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (17): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (18): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (19): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (20): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (21): bottleneck_IR_SE(
#       (shortcut_layer): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=512)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (22): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=512)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (23): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=512)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# *This one is not related to the repo..*

# %%
def gen_embds(fs):
    embds, ids = [], []
    for f in tqdm(fs):
        img = cv2.imread(os.path.join(DATA_DIR, 'training-originals', f))
        _id = int(f.split('_')[0].lstrip('0').zfill(1))
        if _id > 6:
            _id = np.nan
        ids.append(_id)
        
        dets = face_detector(img, 1)
        if len(dets) == 0:
            embds.append(np.zeros((512,)))
            continue
            
        landmarks = shape_predictor(img, dets[0])
        face_crop = dlib.get_face_chip(img, landmarks, size=FACE_SIZE, padding=0.2)[:, :, [2, 1, 0]]

        with torch.no_grad():
            embd = model(transform(face_crop).unsqueeze(0).cuda())[0]
        embds.append(embd.cpu().numpy())
        
    return np.asarray(embds), np.asarray(ids)

# %% [markdown]
# See [this](http://dlib.net/face_detector.py.html) cookbook for `dlib` face detection or [this one](http://dlib.net/face_alignment.py.html) for face alignment.

# %%
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !bunzip2 shape_predictor_5_face_landmarks.dat.bz2
# Out:
# --2021-11-01 05:35:09--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2’
#
# shape_predictor_5_f 100%[===================>]   5.44M  14.8MB/s    in 0.4s
#
# 2021-11-01 05:35:10 (14.8 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2’ saved [5706710/5706710]
#
# bunzip2: Output file shape_predictor_5_face_landmarks.dat already exists.

# %%
face_detector = dlib.get_frontal_face_detector()
shape_predictor = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')

# %% [markdown]
# Let's detect face and generate embeddings:

# %%
embds_db, ids_db = gen_embds(files_db)
embds_query, ids_query = gen_embds(files_query)

print(embds_db.shape, ids_db.shape)
print(embds_query.shape, ids_query.shape)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#   0%|          | 0/52 [00:00<?, ?it/s]
# (7, 512) (7,)
# (52, 512) (52,)

# %% [markdown]
# Filter-out images where face wasn't detected:

# %%
inds = np.abs(embds_db).sum(axis=1) > 0

embds_db = embds_db[inds]
ids_db = ids_db[inds]

print(embds_db.shape, ids_db.shape)
# Out:
# (7, 512) (7,)

# %%
inds = np.abs(embds_query).sum(axis=1) > 0

embds_query = embds_query[inds]
ids_query = ids_query[inds]

print(embds_query.shape, ids_query.shape)
# Out:
# (35, 512) (35,)

# %% [markdown]
# Just sanity check:

# %%
assert np.unique(ids_db).size == ids_db.max() + 1

# %% [markdown]
# # 2nd-level predictor

# %% [markdown]
# Let's manually define useful metrics for clarity:

# %%
def cosine_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def cosine_dist(v1, v2):
    return 1 - cosine_sim(v1, v2)

# %%
def euc_dist(v1, v2):
    return np.linalg.norm(v1 - v2)

# %% [markdown]
# *(you can find them into numpy / scipy / sklearn etc)*

# %%
dist_f = cosine_dist

# %%
classifier = knn.KNeighborsClassifier(n_neighbors=1, metric=dist_f, n_jobs=-1)
classifier.fit(embds_db, ids_db)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                      metric=<function cosine_dist at 0x7f064cd55290>,
#                      metric_params=None, n_jobs=-1, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
ids_pred = classifier.predict(embds_query)

print(ids_pred.shape)
# Out:
# (35,)

# %%
idx_known = ~np.isnan(ids_query)
idx_unknown = np.isnan(ids_query)

# %%
print(balanced_accuracy_score(ids_query[idx_known], ids_pred[idx_known]))
# Out:
# 0.9047619047619048

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Prerequisites

# %%
def plot_matrix(cm, title='Contingency matrix', normed=False):
    if normed:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(10, 10))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title, fontsize=20)
#     plt.colorbar()

    _format = '.2f' if normed else ''
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], _format), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize=20)

    plt.tight_layout()
    plt.ylabel('True label', fontsize=18)
    plt.xlabel('Predicted label', fontsize=18)

# %%
def plot_hists(dists_pos, dists_other, dists_neg, nbins=100):
    plt.figure(figsize=(15, 5))

    plt.hist(dists_pos, color='r', bins=nbins, alpha=0.5, label='positive')
    plt.hist(dists_other, color='g', bins=nbins, alpha=0.5, label='other')
    plt.hist(dists_neg, color='b', bins=nbins, alpha=0.5, label='negative')

    plt.legend(fontsize=14)
    plt.grid(True)

# %%
def plot_far_frr(xs, ys, thrs):
    plt.figure(figsize=(15, 5))

    plt.plot(xs, ys, 'r')
    plt.grid(True)

    for x, y in zip(xs, ys):
        plt.stem([x], [y], 'k--')
    for i, thr in enumerate(thrs):
        plt.text(
            xs[i], ys[i] + 0.01, str(round(thr, 2)),
            horizontalalignment='center', verticalalignment='bottom', fontsize=14, fontweight='bold'
    )

    plt.xlabel('FAR', fontsize=18)
    plt.ylabel('FRR', fontsize=18)

    plt.tick_params(labelsize=14)

# %%
def plot_thresholds(xs, ys, thrs):
    plt.figure(figsize=(15, 5))

    plt.plot(thrs, xs, 'b', label='FAR', linewidth=2.0)
    plt.plot(thrs, ys, 'g', label='FRR', linewidth=2.0)
    plt.grid(True)

    plt.xlabel('threshold (distance)', fontsize=18)
    plt.ylabel('rate', fontsize=18)

    plt.legend(fontsize=14)
    plt.tick_params(labelsize=14)

# %% [markdown]
# Here we go..

# %%
cm = confusion_matrix(ids_query[idx_known], ids_pred[idx_known])

# %%
plot_matrix(cm, normed=True)

# %% [markdown]
# ## Embedding analysis

# %% [markdown]
# Prepare for Embedding Projector visualization:

# %%
f_data = open('arface_cbcl.tsv', 'w')

for embd in embds_query:
    f_data.write('\t'.join([str(round(v, 4)) for v in embd]) + '\n')
    
f_data.flush()
f_data.close()

# %%
f_meta = open('arface_cbcl_meta.tsv', 'w')

f_meta.write('true\tpredicted\n')

for id1, id2 in zip(ids_query, ids_pred):
    if np.isnan(id1):
        f_meta.write('stranger\tperson{}\n'.format(int(id2)))
    else:
        f_meta.write('person{}\tperson{}\n'.format(int(id1), int(id2)))
    
f_meta.flush()
f_meta.close()

# %% [markdown]
# ---

# %%
dmtx_db_query = np.empty((len(ids_db), len(ids_query)))

for i_db, embd_db in enumerate(tqdm(embds_db)):
    for i_query, embd_query in enumerate(embds_query):
        dmtx_db_query[i_db, i_query] = dist_f(embd_db, embd_query)
        
print(dmtx_db_query.shape)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# (7, 35)

# %%
idx_pred = dmtx_db_query.argmin(0)
ids_pred_ = np.asarray([ids_db[_id] for _id in idx_pred])

# %% [markdown]
# Sanity check:

# %%
(ids_pred[idx_known] - ids_pred_[idx_known]).sum()
# Out:
# 0

# %%
dists_pos, dists_other, dists_neg = [], [], []

for c in tqdm(np.unique(ids_db)):
    embds_pos = embds_query[ids_query == c]
    idx = np.arange(len(embds_pos))
    for id1, id2 in itertools.combinations(idx, 2):
        dist = dist_f(embds_pos[id1], embds_pos[id2])
        dists_pos.append(dist)
        
    embds_other = embds_query[(idx_known) & (ids_query != c)]
    for embd_pos in embds_pos:
        for embd_other in embds_other:
            dist = dist_f(embd_pos, embd_other)
            dists_other.append(dist)
        
dists_neg = dmtx_db_query[:, idx_unknown].flatten()
        
print(len(dists_pos), len(dists_other), len(dists_neg))
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# 25 412 91

# %%
plot_hists(dists_pos, dists_other, dists_neg, nbins=10)
plt.stem([0.38], [90], 'r--')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %% [markdown]
# ## FAR/FRR

# %%
thrs = np.linspace(0.3, 0.8, 11)

# %%
thrs
# Out:
# array([0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 ])

# %%
fars, frrs = [], []

dsts_pred = dmtx_db_query.min(0)
print(dsts_pred.shape)

for thr in tqdm(thrs):
    far = (dsts_pred[idx_unknown] <= thr).sum() / len(ids_query)
    fars.append(far)
    
    frr = (dsts_pred[idx_known] > thr).sum() / len(ids_query)
    frrs.append(frr)

#     break

fars = np.asarray(fars)
frrs = np.asarray(frrs)

print(fars.shape, frrs.shape)
# Out:
# (35,)
#   0%|          | 0/11 [00:00<?, ?it/s]
# (11,) (11,)

# %%
fars
# Out:
# array([0.        , 0.        , 0.        , 0.05714286, 0.11428571,
#        0.28571429, 0.34285714, 0.34285714, 0.34285714, 0.34285714,
#        0.34285714])

# %%
frrs
# Out:
# array([0.4       , 0.34285714, 0.34285714, 0.31428571, 0.25714286,
#        0.22857143, 0.2       , 0.11428571, 0.08571429, 0.05714286,
#        0.        ])

# %%
plot_far_frr(fars, frrs, thrs)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
plot_thresholds(fars, frrs, thrs)
